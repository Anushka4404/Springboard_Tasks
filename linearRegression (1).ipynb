# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('advertisement.csv')
print(df)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data=df.drop('Unnamed: 0',axis=1)

# %%
#X=data.drop('Sales',axis=1)
X=data['TV']

# %%
Y=data['Sales']

# %%
x
# Out:
# 0      19
# 1      35
# 2      26
# 3      27
# 4      19
#        ..
# 395    46
# 396    51
# 397    50
# 398    36
# 399    49
# Name: Age, Length: 400, dtype: int64

# %%
y
# Out:
# 0      19000
# 1      20000
# 2      43000
# 3      57000
# 4      76000
#        ...
# 395    41000
# 396    23000
# 397    20000
# 398    33000
# 399    36000
# Name: EstimatedSalary, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
X_train
# Out:
# 234    38
# 45     23
# 171    34
# 47     27
# 265    42
#        ..
# 343    47
# 359    42
# 323    48
# 280    59
# 8      25
# Name: Age, Length: 280, dtype: int64

# %%
Y_train
# Out:
# 234    112000
# 45      20000
# 171    115000
# 47      54000
# 265    108000
#         ...
# 343     51000
# 359     54000
# 323     30000
# 280     88000
# 8       33000
# Name: EstimatedSalary, Length: 280, dtype: int64

# %%
X_test.shape
# Out:
# (120,)

# %%
model=LinearRegression()

# %%
# Reshape X_train to be a 2D array
X_train_reshaped = X_train.values.reshape(-1, 1)  # Use .values to get the underlying NumPy array

# Fit the model using the reshaped data
model.fit(X_train_reshaped, Y_train)
# Out:
# LinearRegression()

# %%
model.fit(df[['TV']],df['Sales'])
# Out:
# LinearRegression()

# %%
model.predict([[66.7]])
# Out:
# C:\Users\anush\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.20328747])

# %%
# Reshape X_test to be a 2D array
X_test_reshaped = X_test.values.reshape(-1, 1)

# Now predict using the reshaped X_test
y_pred = model.predict(X_test_reshaped)
# Out:
# C:\Users\anush\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred=model.predict(X_test_reshaped)
# Out:
# C:\Users\anush\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([8.98159581, 9.17174237, 8.64883932, 8.79144925, 8.60130268,
#        9.21927901, 8.98159581, 8.79144925, 8.98159581, 8.41115612,
#        8.88652253, 9.02913245, 8.83898589, 8.60130268, 9.88479198,
#        9.50449885, 8.93405917, 8.88652253, 8.69637596, 8.45869276,
#        8.88652253, 8.36361948, 8.36361948, 7.93578972, 9.88479198,
#        8.7439126 , 8.2685462 , 9.74218205, 8.12593628, 9.17174237,
#        8.69637596, 9.40942557, 9.21927901, 9.36188893, 9.64710877,
#        9.83725533, 8.55376604, 8.69637596, 8.2685462 , 8.93405917,
#        7.98332636, 8.31608284, 8.64883932, 9.59957213, 9.78971869,
#        8.41115612, 8.93405917, 8.36361948, 8.79144925, 9.64710877,
#        8.36361948, 8.88652253, 8.93405917, 8.69637596, 9.31435229,
#        8.88652253, 9.59957213, 9.26681565, 8.98159581, 9.88479198,
#        8.69637596, 9.26681565, 8.88652253, 8.64883932, 8.2685462 ,
#        8.93405917, 9.26681565, 8.98159581, 8.17347292, 8.79144925,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE=mean_absolute_error(Y_test,y_pred)
MAE
# Out:
# 66624.49474358642

# %%
MSE=mean_squared_error(Y_test,y_pred)

# %%
RMSE = np.sqrt(MSE)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# -4.965872393094346

# %%
n = len(Y_test)  # Number of observations
k = 1  # Number of predictors (excluding the intercept)

# %%
r2 = r2_score(Y_test, y_pred)

# %%
adjusted_r2 = 1 - ((1 - r2) * (n - 1)) / (n - k - 1)

# %%
print(adjusted_r2)
# Out:
# -5.016430633713789

# %%
MAE
# Out:
# 66624.49474358642

# %%
MSE
# Out:
# 5332687841.026829

# %%
RMSE
# Out:
# 73025.25481658266
